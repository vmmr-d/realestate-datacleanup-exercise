# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
#Cálculo de la casa mas cara
casa_mas_cara = ds.price.max()

#Cálculo de indice y de direccion de la casa
dirección_cmc = ds.address[ds[ds['price'] == casa_mas_cara].index[0]]

#Impresión de dato solicitado
print(f"La casa con dirección en {dirección_cmc} es la más cara y su precio es de {casa_mas_cara} €")
# Out:
# La casa con dirección en El Escorial es la más cara y su precio es de 8500000 €

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
#Cálculo de la casa más barata filtrando del dataset los precios diferentes de cero
casa_mas_barata = ds[ds['price'] != 0]['price'].min()

#Cálculo de indice y dirección de la casa
dirección_cmb = ds.address[ds[(ds['price'] != 0) & (ds['price'] == casa_mas_barata)].index[0]]

#Impresión de dato solicitado
print(f"La casa con dirección en {dirección_cmb} es la más económica y su precio es de {casa_mas_barata} €")
# Out:
# La casa con dirección en Berlin, Coslada es la más económica y su precio es de 600 €

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
#Calculo de casa más grande
casa_mas_grande = ds.surface.max()

#Calculo de indice y dirección de la casa
dirección_cmg = ds.address[ds.surface.idxmax()]

#Impresión del dato solicitado
print(f"La casa mas grande está ubicada en {dirección_cmg} y su superficie es de {casa_mas_grande} metros")

#Calculo de casa más pequeña
casa_mas_pequeña = ds.surface.min()

#Calculo de indice y dirección de la casa
dirección_cmp = ds.address[ds.surface.idxmin()]

#Impresión del dato solicitado
print(f"La casa mas pequeña está ubicada en {dirección_cmp} y su superficie es de {casa_mas_pequeña} metros")
# Out:
# La casa mas grande está ubicada en Sevilla la Nueva y su superficie es de 249000.0 metros
# La casa mas pequeña está ubicada en Calle Amparo,  Madrid Capital y su superficie es de 15.0 metros

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
#Cálculo de cuantos datos únicos están en la columna indicada
poblaciones = len(ds.level5.unique())

#Impresión de cantidad de poblaciones en el dataset y datos en la columna
print(f"Hay {poblaciones} poblaciones en el dataset:")
print(ds.level5.unique() + ",")
# Out:
# Hay 168 poblaciones en el dataset:
# ['Arganda del Rey,' 'Fuenlabrada,' 'Boadilla del Monte,'
#  'Las Rozas de Madrid,' ' Madrid Capital,' 'Villaviciosa de Odón,'
#  'Pinto,' 'Valdemoro,' 'Navalcarnero,' 'Pozuelo de Alarcón,'
#  'Torrejón de Ardoz,' 'Navalagamella,' 'San Sebastián de los Reyes,'
#  'Rivas-vaciamadrid,' 'Alpedrete,' 'Móstoles,' 'San Fernando de Henares,'
#  'Coslada,' 'Becerril de la Sierra,' 'Alcalá de Henares,' 'Chinchón,'
#  'Parla,' 'Alcorcón,' 'El Escorial,' 'Leganés,' 'Pedrezuela,'
#  'Majadahonda,' 'Villanueva de la Cañada,' 'Villanueva del Pardillo,'
#  'Torrelodones,' 'Moralzarzal,' 'Mejorada del Campo,' 'Aranjuez,' 'Corpa,'
#  'Getafe,' 'Velilla de San Antonio,' 'Sevilla la Nueva,'
#  'San Martín de la Vega,' 'Villalbilla,' 'Collado Villalba,' 'Alcobendas,'
#  'El Molar (Madrid),' 'Moraleja de Enmedio,' 'Algete,' 'Campo Real,'
#  'Torrejón de la Calzada,' 'Colmenar Viejo,' 'Valdemorillo,'
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
#Impresión de información solicitada
print(ds.isnull())
# Out:
#        Unnamed: 0  id_realEstates  isNew  realEstate_name  phone_realEstate  \
# 0           False           False  False            False             False
# 1           False           False  False            False             False
# 2           False           False  False            False             False
# 3           False           False  False            False             False
# 4           False           False  False            False             False
# ...           ...             ...    ...              ...               ...
# 15330       False           False  False            False             False
# 15331       False           False  False            False             False
# 15332       False           False  False            False             False
# 15333       False           False  False            False             False
# 15334       False           False  False            False             False
#
# ...

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
#Impresión de total de valores nulos
print("Resumen de Valores Nulos:")
print(ds.isnull().sum())

#Eliminación de columnas con valores nulos
ds1 = ds.drop(columns = ['level4', 'level6', 'level7', 'level8'])
ds1 = ds1.loc[:, (ds1.notna().any()) & ((ds1 != 0).any())]

#Eliminación de valores cero en columnas de superficie y precio
ds1 = ds1[(ds1['surface'] > 0) & (ds1['price'] != 0)]

#Columnas del dataset eliminadas
columnas_eliminadas = set(ds.columns) - set(ds1.columns)

#Impresión de comparativa de datasets y columnas eliminadas
print(f'\nColumnas eliminadas: {columnas_eliminadas}')
print(f'\nAntes de limpiar datos: {ds.shape}')
print(f'Después de limpiar datos: {ds1.shape}')
# Out:
# Resumen de Valores Nulos:
# Unnamed: 0              0
# id_realEstates          0
# isNew                   0
# realEstate_name        10
# phone_realEstate      794
# url_inmueble            0
# rooms                 353
# bathrooms             345
# surface              1250
# price                   0
# date                    0
# description           142
# address                 0
# country                 0
# level1                  0
# level2                  0
# level3                  0
# level4               6643
# level5                  0
# level6              14627
# level7               2277
# level8               8579
# upperLevel              0
# countryId               0
# level1Id                0
# level2Id                0
# level3Id                0
# level4Id                0
# level5Id                0
# level6Id                0
# level7Id                0
# level8Id                0
# accuracy                0
# latitude                0
# ...

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
#Importar biblioteca adicionales
import numpy as np

#Cálculo de dato solicitado
media = ds1.price[ds1.level5 == 'Arroyomolinos (Madrid)'].mean()

#Impresión de dato solicitado
print(f"La media de precios en la popblación de 'Arroyomolinos (Madrid)' es: {media:.2f} €")
# Out:
# La media de precios en la popblación de 'Arroyomolinos (Madrid)' es: 299892.69 €

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
#Importar bibliotecas adicionales
import matplotlib.pyplot as plt
# %matplotlib inline

#calcular datos a graficar y realizar gráfico
Arroyo = ds1[ds1.level5 == 'Arroyomolinos (Madrid)']
Arroyo['price'].plot(kind = 'hist', alpha = 0.6, legend = True)

#Configurar Etiquetas y Título
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.title('Histograma de Precio para Arroyomolinos (Madrid)')
plt.grid(True)

#Mostrar el gráfico
plt.show()

# %% [markdown]
# El Histograma de Precio de Casas para la población de Arroyomolinos (Madrid) refleja una tendencia de precios establecidos en el rango de 190000 a 400000 euros, siendo el promedio de 299892.69 euros, como se indica más arriba en el ejercicio 07.

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
#Cálculo de precio promedio en la población de Valdemorillo
mediaValdemorillo = ds1.price[ds1.level5 == 'Valdemorillo'].mean()

#Impresión del precio promedio de Valdemorillo
print(f"La media de precios en la población de 'Valdemorillo' es: {mediaValdemorillo:.2f} euros")

#Cálculo de precio promedio en la población de Galapagar
mediaGalapagar = ds1.price[ds1.level5 == 'Galapagar'].mean()

#Impresión del precio promedio de Galapagar
print(f"La media de precios en la población de 'Galapagar' es: {mediaGalapagar:.2f} euros")
# Out:
# La media de precios en la población de 'Valdemorillo' es: 371583.02 euros
# La media de precios en la población de 'Galapagar' es: 372108.65 euros

# %% [markdown]
# Observando la media de precios de estas dos poblaciones se puede concluir que la distribución de precios tienen precios muy cercanos entre sí

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
#Cálculo de precio por metro cuadrado (pps) para añadir como columna nueva al dataset
ds1['pps'] = ds1['price'] / ds1['surface']

#Cálculo e Impresión del promedio pps de la poblacion de 'Valdemorillo'
ppsv = ds1.pps[ds1.level5 == 'Valdemorillo'].mean()
print(f"La media pps para la población de 'Valdemorillo' es de {ppsv:.2f} €/m2")

#Cálculo e Impresión del promedio pps de la población de 'Galapagar'
ppsg = ds1.pps[ds1.level5 == 'Galapagar'].mean()
print(f"La media pps para la población de 'Galapagar' es de {ppsg:.2f} €/m2")
# Out:
# La media pps para la población de 'Valdemorillo' es de 1317.95 €/m2
# La media pps para la población de 'Galapagar' es de 1606.32 €/m2

# %% [markdown]
# Los datos proporcionados sugieren que el mercado inmobiliario de Galapagar es más caro que el de Valdemorillo. Sin embargo, para comprender completamente las razones de esta diferencia sería necesario realizar un analisís más profundo considerando diversos factores socioeconómicos y demográficos.

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
ds2 = ds1[ds1.surface < 5000]
ds2.plot.scatter(y= 'price', x= 'surface', title = 'Relación entre superficie y Precio de las Casas' )
# Out:
# <Axes: title={'center': 'Relación entre superficie y Precio de las Casas'}, xlabel='surface', ylabel='price'>

# %% [markdown]
# El gráfico generado muestra como aumenta el precio a medida que aumenta la superficie, aunque también se observa valores atípicos.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
#Cálculo e Impresion de cantidad total de agencias inmobiliarias en el dataset
inmobiliarias = len(ds1.realEstate_name.unique())
print(f"Hay {inmobiliarias} Agencias de Bienes Raíces en el dataset")
# Out:
# Hay 1707 Agencias de Bienes Raíces en el dataset

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
#Cálculo de la población con mayor cantidad de casas
población_mf = ds1['level5'].value_counts().idxmax()

#Cálculo de la cantidad de casas que tiene la población mas frecuente
frecuencia = ds1['level5'].value_counts().max()

#Impresión de información solicitada
print(f"La poblacion de {población_mf} tiene {frecuencia} de casas")
# Out:
# La poblacion de  Madrid Capital tiene 6228 de casas

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
#Asignación de variable para las columnas a filtrar
columnas = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']

#Nuevo Dataframe Cinturon Sur CS, subconjunto con la información solicitada a partir del Dataframe original ds
CS = ds[ds['level5'].isin(columnas)]

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
#Cálculo de la mediana de los precios usando dataset CS
mediana = CS.groupby('level5')['price'].median()

#Codigo para generar un grafico de barras y su impresión
plt.figure(figsize = (8,6))
mediana.plot(kind = 'bar', color = 'skyblue')
plt.title('Mediana de los precios por Población')
plt.xlabel('Poblacion')
plt.ylabel('Mediana del Precio')
plt.xticks(rotation = 45)
plt.tight_layout()

plt.show()

# %% [markdown]
# En el gráfico de barras generado se puede observar que la población de 'Getafe' es la que tiene el precio de casas mas alto mientras que la población de 'Fuenlabrada' es la que tiene el precio de casas más económico y por último las otras dos poblaciones ('Alcorcón', 'Leganés')  tienen un precio de casas similares.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
#Asignacion de una variable con las columnas de interés
Columnas_interés = ['bathrooms', 'price', 'rooms', 'surface']

#Calculo de la media y varianza para cada una de las columnas seleccionadas
media = CS[Columnas_interés].mean()
varianza = CS[Columnas_interés].var()

#Impresion de los datos solicitados
print('Media de las variables seleccionadas:')
print(media)
print('\nVarianza muestral de las variables seleccionadas')
print(varianza)
# Out:
# Media de las variables seleccionadas:
# bathrooms         1.633222
# price        223094.480706
# rooms             3.017738
# surface         111.752224
# dtype: float64
#
# Varianza muestral de las variables seleccionadas
# bathrooms    5.717969e-01
# price        1.492137e+10
# rooms        7.188859e-01
# surface      4.263052e+03
# dtype: float64

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
#Asignación de variable para las columnas de interés
Columnas_a_usar = ['level5', 'address', 'price']

#Codigo para calcular la casa mas cara de cada población
casas_mas_caras = CS.loc[CS.groupby('level5')['price'].idxmax(), Columnas_a_usar]

#Imprersion de cada casa con dirección y precio
for index, row in casas_mas_caras.iterrows():
    print(f"La casa mas cara de {row['level5']} está en la dirección {row['address']} con un precio de {row['price']}€")
# Out:
# La casa mas cara de Alcorcón está en la dirección Alcorcón con un precio de 950000€
# La casa mas cara de Fuenlabrada está en la dirección Calle de Paulo Freire, 5, Fuenlabrada con un precio de 490000€
# La casa mas cara de Getafe está en la dirección Getafe con un precio de 1050000€
# La casa mas cara de Leganés está en la dirección Avenida Reina Sofía, Leganés con un precio de 650000€

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
#Importando la biblioteca adicional requerida
from scipy.stats import zscore

#Normalizacion de precios usando zscore
CS = CS.copy()
CS.loc[:, 'precio_normalizado'] = CS.groupby('level5')['price'].transform(zscore)

#Codigo para generar histograma
plt.figure(figsize=(10, 6))

poblaciones = CS['level5'].unique()

for x in poblaciones:
    precios_norm = CS[CS['level5'] == x]['precio_normalizado']
    plt.hist(precios_norm, bins=10, alpha=0.5, label=f'Población: {x}', density=True)

plt.title('Distribución de Precios Normalizados por Población')
plt.xlabel('Precio Normalizado (Z-score)')
plt.ylabel('Densidad')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Como se puede observar la población de 'Getafe' es la que presenta desviación con respecto a las demas poblaciones.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
#Creacion de columna nueva pps para el dataframe CS
CS['pps'] = CS.price / CS.surface

#Calculo e Impresión de media de pps para las poblaciones de interés
ppsGetafe = CS[CS.level5 == 'Getafe'].pps.mean()
ppsAlcorcón = CS[CS.level5 == 'Alcorcón'].pps.mean()

print(f"El precio por metro cuadrado en 'Getafe' es de {ppsGetafe:.2f} €/m2")
print(f"El precio por metro cuadrado en 'Alcorcón' es de {ppsAlcorcón:.2f} €/m2")
# Out:
# El precio por metro cuadrado en 'Getafe' es de 2066.31 €/m2
# El precio por metro cuadrado en 'Alcorcón' es de 2239.30 €/m2

# %% [markdown]
# El hecho de que en Getafe esté la propiedad más cara (ejercicio 17) pero un precio promedio por metro cuadrado más bajo sugiere una mayor variabilidad en los precios de las propiedades en Getafe comparado con Alcorcón. Estas diferencias en los precios podrían deberse a factores como la ubicación específica dentro de cada municipio, el tipo de propiedades disponibles, la demanda local, o las características particulares de las viviendas más caras en cada área.

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
#Codigo para crear la figura y los subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
fig.suptitle('Gráficos de Dispersión por Población', fontsize=16)

poblaciones = CS['level5'].unique()

for i, poblacion in enumerate(poblaciones):
    row = i // 2
    col = i % 2
    
    data = CS[CS['level5'] == poblacion]
    
    #Creación del diagrama de dispersión
    axs[row, col].scatter(data['surface'], data['price'], alpha=0.6)
    
    #Personalización de la figura
    axs[row, col].set_title(f'Población: {poblacion}')
    axs[row, col].set_xlabel('Superficie (m²)')
    axs[row, col].set_ylabel('Precio (€)')
    axs[row, col].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps

# Mapa centrado en (60 grados latitud y -2.2 grados longitud)
# Latitud, longitud
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.OpenStreetMap.Mapnik)
map
# Out:
# Map(center=[60, -2.2], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
#Importando bibliotecas adicionales
from ipyleaflet import MarkerCluster, CircleMarker, AwesomeIcon, Marker
CS['latitude'] = CS['latitude'].str.replace(',', '.').astype(float)
CS['longitude'] = CS['longitude'].str.replace(',', '.').astype(float)

#Diccionario de las columnas 'latitude' y 'longitude' del dataframe CS
coordenadas = CS.groupby('level5')[['latitude', 'longitude']].apply(lambda x: x.to_dict(orient='records')).to_dict()

#Asignación de colores para cada población
colores = {
    'Getafe': 'red',
    'Alcorcón': 'blue',
    'Leganés': 'green',
    'Fuenlabrada': 'purple'
}

#Centrando mapa a la localidad de Madrid, España
mapa = Map(center=(40.4168, -3.7038), zoom=10)

#Creacion de marcadores para las coordenadas
marcadores = []

for level5, coordenadas in coordenadas.items():
    color = colores.get(level5,'gray')  # Default color si no se encuentra en el diccionario
    for coord in coordenadas:
        marcador = CircleMarker(
            location=(coord['latitude'], coord['longitude']),
            radius=5,
            color=color,
            fill_color=color,
            fill_opacity=0.7
        )
        marcadores.append(marcador)

for marcador in marcadores:
    mapa.add_layer(marcador)

#Ubicacion de poblaciones de interés
legend_locations = {
    'Getafe': (40.3, -3.7),
    'Alcorcón': (40.35, -3.8),
    'Leganés': (40.32, -3.75),
    'Fuenlabrada': (40.28, -3.8)
}

for poblacion, color in colores.items():
    icono = AwesomeIcon(name='circle', marker_color=color, icon_color='white')
    marcador_leyenda = Marker(icon=icono, location=legend_locations[poblacion])
    mapa.add_layer(marcador_leyenda)

mapa
# Out:
# Map(center=[40.4168, -3.7038], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zo…
